# %% [markdown]
# ## Import and Setup

# %%
from itertools import chain
import glob
import pandas as pd
import re
import numpy as np
import nltk
import math
from nltk.tag import CRFTagger
import pycrfsuite
from hmmlearn import hmm
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import classification_report, confusion_matrix
#import dateparser
#from dateparser.search import search_dates

#nltk.download()

# %% [markdown]
# ## Functions

# %%
def save_as_csv(filename, dataframe) :
    dataframe.to_csv(filename, encoding='utf-8')

# %%
def read_csv(path, last_column):
    data_input = pd.read_csv(path, header=0, usecols=range(1,last_column))
    data_frame_input = pd.DataFrame(data = data_input)
    return data_frame_input

# %%
def get_promo_data_index(data):
    numpy_data = data.copy(deep=True)
    numpy_data = np.array(numpy_data)
    new_data = []
    for i in range(len(numpy_data)):
        if (numpy_data[i][2] == 1):
            new_data.append(i)
    new_data = np.array(new_data)
    return (new_data)

def get_promo_data(data):
    numpy_data = data.copy(deep=True)
    numpy_data = np.array(numpy_data)
    new_data = []
    for i in range(len(numpy_data)):
        if (numpy_data[i][2] == 1):
            new_data.append(numpy_data[:,[0,1]][i])
    new_data = np.array(new_data)
    new_data = pd.DataFrame(data=new_data,columns=["tweet","username"])
    return (new_data)

# %%
def get_url(text):
    result = re.findall(r"http\S+",text)
    return(result)

def get_url_data(data):
    numpy_data = data.copy(deep=True)
    numpy_data = np.array(numpy_data)
    new_data = []
    for i in range(len(numpy_data)):
        url_result = get_url(numpy_data[i][0])
        new_data.append(url_result)
    new_data = np.array(new_data)
    new_data = pd.DataFrame(new_data,columns=["urls"])
    return(new_data)

# %%
def get_number(text):
    filter_text = re.sub(r"http\S+", "", text)
    result = re.findall(r"[0-9]\S+",filter_text)
    return (result)

def get_number_data(data):
    numpy_data = data.copy(deep=True)
    numpy_data = np.array(numpy_data)
    new_data = []
    for i in range(len(numpy_data)):
        number_result = get_number(numpy_data[i][0])
        new_data.append(number_result)
    new_data = np.array(new_data)
    new_data = pd.DataFrame(new_data,columns=["number"])
    return(new_data)

print(get_number("15rb"))
# Out:
# ['15rb']

# %%
def get_discount(text):
    #result = re.findall(r"(?:[a-zA-Z'-]+[^a-zA-Z'-]+){0,2}\S+%(?:[^a-zA-Z'-]+[a-zA-Z'-]+){0,2}",text)
    result = re.findall(r"\S+%",text)
    return (result)

def get_discount_data(data):
    numpy_data = data.copy(deep=True)
    numpy_data = np.array(numpy_data)
    new_data = []
    for i in range(len(numpy_data)):
        result = get_discount(numpy_data[i][0])
        new_data.append(result)
    new_data = np.array(new_data)
    new_data = pd.DataFrame(new_data,columns=["discount"])
    return(new_data)

print(get_discount("Diskon ini 10000% dari biasanya"))
# Out:
# ['10000%']

# %%
def get_price(text):
    filter_text = re.sub(r"http\S+", "", text)
    filter_text = re.sub(r"08[0-9]\S+", "", filter_text)
    filter_text = re.sub(r"\s*k", ".000", filter_text)
    filter_text = re.sub(r"\s*rb\w*", ".000", filter_text)
    filter_text = re.sub(r"\s*ribu\w*", ".000", filter_text)
    filter_text = re.sub(r"\s*rebu\w*", ".000", filter_text)
    filter_text = re.sub(r"\s*jt\w*", ".000.000", filter_text)
    filter_text = re.sub(r"\s*juta\w*", ".000.000", filter_text)    
    filter_text = re.sub(r"[^\s0-9.]", "", filter_text)
    
    result = re.findall(r"[1-9]+\S+.[0-9]+[0]{2}",filter_text)
    return (result)

def get_price_data(data):
    numpy_data = data.copy(deep=True)
    numpy_data = np.array(numpy_data)
    new_data = []
    for i in range(len(numpy_data)):
        result = get_price(numpy_data[i][0])
        new_data.append(result)
    new_data = np.array(new_data)
    new_data = pd.DataFrame(new_data,columns=["price"])
    return(new_data)

print(get_price("0857-000 rp15rb rp15ribuan rp15juta 15 juta 15 puluh puluh juta 15jt 15.000 15.00"))
# Out:
# ['15.000', '15.000', '15.000.000', '15.000.000', '15.000.000', '15.000']

# %%
def get_date(text):
    result = ""
    return result
    
def get_date_data(data):
    numpy_data = data.copy(deep=True)
    numpy_data = np.array(numpy_data)
    new_data = []
    for i in range(len(numpy_data)):
        date_result = get_date(numpy_data[i][0])
        new_data.append(date_result)
    new_data = np.array(new_data)
    new_data = pd.DataFrame(new_data,columns=["date"])
    return(new_data)

print(get_date("1 1 2018"))

# %%
def merge_data(datas1, datas2):
    np1 = np.array(datas1)
    np2 = np.array(datas2)
    column1 = datas1.columns.values
    column2 = datas2.columns.values
    columnresult = np.append(column1,column2, axis=0)
    result = np.append(np1, np2, axis=1)
    result = pd.DataFrame(data=result, columns=columnresult)
    return (result)

# %%
def get_by_index(data,index_array):
    numpy_data = data.copy(deep=True)
    numpy_data = np.array(numpy_data)
    new_data = []
    check_index = 0
    for i in range(len(numpy_data)):
        if (check_index < len(index_array)) and (i == index_array[check_index]):
            check_index = check_index + 1
            new_data.append(numpy_data[i])
    new_data = np.array(new_data)
    new_data = pd.DataFrame(data=new_data,columns=["tweet","username"])
    return new_data

# %% [markdown]
# ## Main

# %%
raw_data = read_csv("integrated_data/integrated_with_label(full).csv",4)
print(raw_data)
# Out:
#                                                       0                1    2
# 0      ya anjir cpt bgt ya abis barang manusia diskon:(         SOHEEDCH  0.0
# 1     lazada 11.11.2019 diskon terbesar 24 jam https...        Vallno_07  1.0
# 2     selama kalo liat promo diskon 70% + 30% dalem ...         bayu_joo  0.0
# 3     apa bedanya matahari sama bulan?  matahari ada...       Hanifati_f  0.0
# 4     @garudacares bagaimana cara tukar mileage disk...           Nug_QA  1.0
# 5     @gencamon nahiya benerrr hahahaha kalo makan c...         primetam  0.0
# 6            fak gmarket kenapa diskon nya sekarang sih       singularyv  0.0
# 7     sejarah asia tenggara karya m.c. ricklefs rp 3...   KomunitasBambu  1.0
# 8     @amingcoffee transmart kuburaya diskon, kapan ...      kalbarinfo_  0.0
# 9     tah diskon 50% cenah..  yuk diserbu..   https:...   AmaAbiyyunShoh  1.0
# 10    @wongalas901 @prabowo @aniesbaswedan rika wis ...     Dianhandoko6  0.0
# 11    sebenarnya bahagia itu sederhana... - beli ini...        anggieppu  0.0
# 12    yuhuu..  siapa lagi yang mau order deodorantny...  indri_indriyuni  0.0
# 13    @febjae iya teh ambil aja yang kuning mah. dis...         favechan  0.0
# 14    pesta harga akhir tahun di giias medan auto sh...      IcanIndopro  0.0
# 15    yaampun kak aulll. eh tapi itu make over lagi ...      tyoungjaems  1.0
# 16    @rahagyu29 @bayu_joo jadi misal harganya 100rb...       gardagagar  0.0
# 17    pesta harga akhir tahun di giias medan auto sh...      IcanIndopro  1.0
# 18    hanya hari ini! shopee promo 11.11 big sale! 1...   katalogpromosi  1.0
# 19    @tys1004 mau beli season greetings tia, per ha...        ChocoBee_  0.0
# 20    cgv cinemas kini hadir di icon mall #gresik . ...         GoersApp  1.0
# 21    @princekuaniin fansite kyknya soalnya itu pun ...    aracelli_0129  0.0
# 22    beli tiket kereta api di @tokopedia diskon 20%...        promo_BRI  1.0
# 23    buat kalian yang bisa jajan di alfamart - yuk ...   katalogpromosi  1.0
# 24    starbucks promo diskon 50% untuk pembelian min...   katalogpromosi  1.0
# 25    sempurnakan alat dapurmu yuk! peralatan dapur ...       alfacartID  1.0
# 26    @gramedia handmaid's tale belum ketemu miinn d...          Ljwoori  0.0
# 27    @yrachmania temen gue nitip temennya pas di ho...      urpoisonivy  1.0
# 28    {np} 6 tiket diskon 50% masuk gelanggang samud...     New_preloved  0.0
# 29    kalok minta diskon, telponnyaaaa berkali kalii...     Kmunadiayuna  0.0
# ...                                                 ...              ...  ...
# 1313  the duck king promo diskon rp. 100.000 dengan ...   katalogpromosi  NaN
# 1314  @moontaewin grabfood mbaa kalo di kota gw pake...       laimegreen  NaN
# 1315         @yunishemale klo cowok kurus gak di diskon       ari_udun03  NaN
# 1316  lagi pengen essence saya tu tolong jangan disk...    bvttercookies  NaN
# 1317  mediheal diskon jadi 195. cobaan apa lagi ini....    bvttercookies  NaN
# 1318  perbedaan matahari dengan bulan? matahari ada ...      Sanita_RMCF  NaN
# 1319  @pepisigiro langsung jual murah ya pep, diskon...      rimarimpong  NaN
# 1320  hy grameds! kali ini gramedia memberikan inspi...  gramediapwkerto  NaN
# 1321  diskon hingga 15% di crystal jade dgn cc bca t...     redirectline  NaN
# 1322  lazada bca monday epromo! diskon 10% hingga rp...   katalogpromosi  NaN
# 1323  @syahrul38 @gunromli @muannas_alaidid gak usah...       Aviecena05  NaN
# 1324  udah pada isi saldo tcash nya belum? belanja #...          simPATI  NaN
# 1325  halo, sahabat kai! kami nantikan kehadiranmu d...        hendra_ns  NaN
# 1326  @dardhyrian -berlaku utk semua kartu mandiri d...    mandirifiesta  NaN
# 1327  karena cuma https://t.co/e8cgb948wk online sho...          woodeiy  NaN
# 1328  @dardhyrian mandiri debit &amp;/ kartu kredit ...    mandirifiesta  NaN
# 1329  @dardhyrian utk promo pizza menggunakan fiesta...    mandirifiesta  NaN
# 1330  waterboom lippo cikarang promo diskon 20%* khu...   katalogpromosi  NaN
# 1331  beli pisang dapet diskon manggis cen lek wes s...     cindyatsanio  NaN
# 1332  @yuflyulk hhmm good idea. ntar aku coba nego k...     vousmayvoyez  NaN
# 1333  kalo udah di uninstall, jdid malah lg ngasih d...   bitaheldaroini  NaN
# 1334  @arifhaz_ @sarasarafaina lhoooo saiki jaga di ...       ilmaharani  NaN
# 1335  brt koridor iii siang ini.  ada ibu ibu menyar...    khaerunnisaQM  NaN
# 1336   @sj4th84 belinyaa dimaanaa opp yg dapet diskon ?        instaeng9  NaN
# 1337  road to fantastic 11! rayainnya #belanjabareng...       VIPPlazaID  NaN
# 1338  @instaeng9 [ udah sg nya ga usah, belinya ntar...          SJ4th84  NaN
# 1339  @plscallnuna_ wekawekaweka  diskon laahh 130 o...   LindaWintiasih  NaN
# 1340  @kbltppz @womanfeeds bantu jawab, kmrn aku bel...      intanemaBlb  NaN
# 1341  besooooook  jangan lupa, jam 6 sampe jam 8 pag...     fanifinafoni  NaN
# 1342  @telkompromo hai ka, apakah ada kompensasi jik...          hanitya  NaN
#
# [1343 rows x 3 columns]

# %%
raw_promo_data = get_promo_data(raw_data)
raw_promo_data_index = get_promo_data_index(raw_data)
print(raw_promo_data_index)
print(raw_promo_data)
# Out:
# [  1   4   7   9  15  17  18  20  22  23  24  25  27  30  33  35  36  38
#   39  40  42  43  44  45  47  48  49  52  53  54  55  56  58  59  60  61
#   62  63  64  68  70  72  73  77  78  79  80  81  83  84  85  87  89  90
#   94  95  96  97 100 103 104 105 106 107 108 110 112 114 116 118 119 121
#  122 123 124 126 128 129 131 134 135 136 139 143 145 146 151 152 154 155
#  156 158 162 163 164 167 169 171 172 173 174 175 176 177 179 180 181 187
#  188 190 195 196 198]
#                                                  tweet         username
# 0    lazada 11.11.2019 diskon terbesar 24 jam https...        Vallno_07
# 1    @garudacares bagaimana cara tukar mileage disk...           Nug_QA
# 2    sejarah asia tenggara karya m.c. ricklefs rp 3...   KomunitasBambu
# 3    tah diskon 50% cenah..  yuk diserbu..   https:...   AmaAbiyyunShoh
# 4    yaampun kak aulll. eh tapi itu make over lagi ...      tyoungjaems
# 5    pesta harga akhir tahun di giias medan auto sh...      IcanIndopro
# 6    hanya hari ini! shopee promo 11.11 big sale! 1...   katalogpromosi
# 7    cgv cinemas kini hadir di icon mall #gresik . ...         GoersApp
# 8    beli tiket kereta api di @tokopedia diskon 20%...        promo_BRI
# 9    buat kalian yang bisa jajan di alfamart - yuk ...   katalogpromosi
# 10   starbucks promo diskon 50% untuk pembelian min...   katalogpromosi
# 11   sempurnakan alat dapurmu yuk! peralatan dapur ...       alfacartID
# 12   @yrachmania temen gue nitip temennya pas di ho...      urpoisonivy
# 13   prime gears beri diskon menarik helm arai, tai...      motovaganza
# 14   @fiiildzah @gojekindonesia nggak tau nih kak, ...      ademutiaraa
# 15   sesuai janji kami beberapa bulan lalu, kini pr...          bukugpu
# 16   longdress polos renda ukuran: tercantum di gam...        ria_indra
# 17   gmarket lagi ada diskon mega sale nih,  wanna ...        jinhwiyaa
# 18   @indonesiagaruda sdh dcoba berulang2 malah pas...           Nug_QA
# 19   cardholders, jangan lupa yah kalau mau beli ti...      mandiricard
# 20   @benzbara_ @storialco kalau nggak salah, buat ...         iladelfa
# 21   kamu bakalan dapat diskon 25% kalo beli tiket ...     ecogreenpark
# 22   https://t.co/xvvp3ikdvy bekerja sama dengan ko...     KompasTravel
# 23   #pragiwaksono amsterdam teramat menyenangkan. ...           pandji
# 24   hai millenials bogor, kami akan hadir di botan...  JungleLand_Indo
# 25   halo adakah yg buka go prive shirt yg lg disko...        sooisxing
# 26   #sahabatkai, mulai 25 oktober 2018 pemesanan t...           KAI121
# 27   diskon 30% lho... @ new taipei city https://t....    PrimadonnaINA
# 28   @bayu_joo kalo harga 120.000 didiskon spt diat...   nosa_saraswati
# 29   jual buku serba diskon: sejarah islam di tanah...       eswaachmad
# ..                                                 ...              ...
# 83   barang baruuu. masih anget nihh, tengok yuuuu ...  SepatuDocmartku
# 84   diskon toyota bogor, hub: 085701512000 https:/...    Auto2000Bogor
# 85   flash sale telah dimulai! 100 orang pertama ya...       RedDoorzID
# 86   hai seafood lovers. diskon 50% setiap hari unt...       TM_M2S_APG
# 87   untuk mengawali bulan november ini, cobain pak...          yukk_id
# 88   update apps https://t.co/69vhdymxvc sekarang b...     bliblidotcom
# 89   hey, klik linknya dan download app reddoorz sk...      mridwantama
# 90   periode promo klinik kiara healthcare 1 novemb...  KiaraHealthCare
# 91   lelang online dimulai dari harga 10rb hingga f...     bliblidotcom
# 92   tunggu kehadiran kami di pmps (pasar malam per...   XTSquareOffice
# 93   hai aces, memasuki periode november 2018 ace h...     ACEIndonesia
# 94   lewat aplikasi ini, bisa reservasi restoran pl...        detikfood
# 95   untuk mengawali bulan november ini, cobain pak...          yukk_id
# 96   semalem kepikiran pengen beli primer. tau tau ...       agithapepe
# 97   lewat aplikasi ini, bisa reservasi restoran pl...       foodball33
# 98   lewat aplikasi ini, bisa reservasi restoran pl...    SayaSukaMasak
# 99   lewat aplikasi ini, bisa reservasi restoran pl...         redyvine
# 100  lewat aplikasi ini, bisa reservasi restoran pl...     lezatbergizi
# 101  lewat aplikasi ini, bisa reservasi restoran pl...            fbrdn
# 102  lewat aplikasi ini, bisa reservasi restoran pl...   FineCuisineSmg
# 103  dapatkan tambahan diskon hingga 10% khusus bag...   KartuKreditBCA
# 104  cardholders, sudah waktunya mengganti springbe...      mandiricard
# 105  harga gledek 1 hari lagi! nikmati diskon tiket...            tiket
# 106  dibuka prapesan!  mencari bali yang berubah ka...   basabasi_store
# 107  starbucks promo diskon 50% untuk pembelian min...   katalogpromosi
# 108  #repost hushpuppiesid          calm your day w...       Park23Bali
# 109  #jalanjalangratis #ngilanginstres #ngilanginst...  TiketPesawatPro
# 110  kemarin sebelum ke maiyah, sempet nonton ini j...       ShadaHanin
# 111  cukup dengan membawa minimal 2 orang pendampin...   ancoltmnimpian
# 112  2 bioglass 4jt dapet diskon 300rb dapet lagi g...    sellyriantica
#
# [113 rows x 2 columns]

# %%
url_data = get_url_data(raw_promo_data)

# %%
number_data = get_number_data(raw_promo_data)
for i in range(len(number_data)):
    print(number_data["number"][i])
# Out:
# ['11.11.2019', '24']
# ['70%']
# ['350.000', '210.000', '0813-8543-0505', '08.00-17.00']
# ['50%']
# []
# ['2018!']
# ['11.11', '11.11', '90%']
# ['20%']
# ['20%', '100rb.']
# ['01-15', '2018']
# ['50%']
# ['84%!!']
# ['30rebu']
# ['2018']
# ['10']
# ['25%']
# ['120rb/pcs']
# ['25.500', '34.000', '15.800', '20.000']
# ['70%...benar']
# ['10%']
# ['50ribuan', '50%.']
# ['25%']
# ['1.000.000.']
# []
# ['11', '2018.', '2018goestojungleland']
# ['30%']
# ['25', '2018', '121']
# ['30%']
# ['120.000', '84.000', '36.000', '30%', '10.800,', '25.200']
# []
# ['2..', '10%', '2256ea97']
# ['2018:', '90%']
# ['2018:', '90%']
# []
# []
# ['110rb/pcs']
# ['7.500']
# []
# []
# ['790k', '560k']
# []
# ['15%', '1,2', '04']
# ['15%', '1,2', '04']
# []
# ['100%', '70%.']
# []
# []
# ['75%']
# ['150.000']
# []
# ['085701512000']
# []
# ['12', '30%']
# ['20%']
# ['60-80%', '20rb']
# ['10%', '15%', '20%', '082324126647']
# ['11/11', '12/12', '11/11', '12/12']
# ['59rb', '1602', '60rb']
# ['13', '89.000', '71.200']
# ['15%', '10%']
# ['11.11']
# ['15%']
# ['10%']
# ['97q9anm2xnt']
# ['50%', '31', '2018']
# ['50%']
# ['15%.', '2018!']
# ['20%', '62816939424']
# ['5%)', '5%)', '5%)', '15%)', '0817-7997-5106)']
# []
# ['10', '1.']
# ['115', '115', '48.000', '3pcs', '46.000']
# ['115', '115', '48.000', '3pcs', '46.000']
# ['30%']
# ['115', '115', '48.000', '3pcs', '46.000']
# ['115', '115', '48.000', '3pcs', '46.000']
# ['115', '115', '48.000', '3pcs', '46.000']
# ['25%', '30', '2018']
# ['1,3', '46', '2018']
# ['50%', '10%!']
# ['60k']
# ['100k', '11.11']
# []
# ['69000', '36-40']
# ['085701512000']
# ['100', '4pm', '25%.']
# ['50%']
# ['10%', '15%']
# ['500rb.']
# ['50.000']
# ['31', '2018', '35%']
# ['10rb', '65%']
# ['2018.']
# ['2018']
# ['50%']
# ['10%', '15%']
# ['60%']
# ['50%']
# ['50%']
# ['50%']
# ['50%']
# ['50%']
# ['50%']
# ['10%', '2018.', '0%', '12']
# ['70%', '10%*', '500']
# ['50%']
# ['70.000', '25%', '15', '276', '0813-1632-0671']
# ['50%']
# ['23']
# []
# []
# ['60.000', '87.500', '50%).']
# ['4jt', '300rb']

# %%
discount_data = get_discount_data(raw_promo_data)
print(discount_data)
# Out:
#        discount
# 0            []
# 1         [70%]
# 2            []
# 3         [50%]
# 4            []
# 5            []
# 6         [90%]
# 7         [20%]
# 8         [20%]
# 9            []
# 10        [50%]
# 11        [84%]
# 12           []
# 13           []
# 14           []
# 15        [25%]
# 16           []
# 17           []
# 18        [70%]
# 19        [10%]
# 20        [50%]
# 21        [25%]
# 22           []
# 23           []
# 24           []
# 25        [30%]
# 26           []
# 27        [30%]
# 28        [30%]
# 29           []
# ..          ...
# 83           []
# 84           []
# 85        [25%]
# 86        [50%]
# 87   [10%, 15%]
# 88           []
# 89           []
# 90        [35%]
# 91        [65%]
# 92           []
# 93           []
# 94        [50%]
# 95   [10%, 15%]
# 96        [60%]
# 97        [50%]
# 98        [50%]
# 99        [50%]
# 100       [50%]
# 101       [50%]
# 102       [50%]
# 103   [10%, 0%]
# 104  [70%, 10%]
# 105       [50%]
# 106       [25%]
# 107       [50%]
# 108          []
# 109          []
# 110          []
# 111       [50%]
# 112          []
#
# [113 rows x 1 columns]

# %%
price_data = get_price_data(raw_promo_data)
print(price_data)
# Out:
#                                          price
# 0                                           []
# 1                                           []
# 2                           [350.000, 210.000]
# 3                                           []
# 4                                           []
# 5                                           []
# 6                                           []
# 7                                           []
# 8                                    [100.000]
# 9                                           []
# 10                                          []
# 11                                          []
# 12                                    [30.000]
# 13                                          []
# 14                                          []
# 15                                          []
# 16                                   [120.000]
# 17            [25.500, 34.000, 15.800, 20.000]
# 18                                          []
# 19                                          []
# 20                                    [50.000]
# 21                                    [25.000]
# 22                                 [1.000.000]
# 23                                          []
# 24                                          []
# 25                                          []
# 26                                          []
# 27                                          []
# 28   [120.000, 84.000, 36.000, 10.800, 25.200]
# 29                                          []
# ..                                         ...
# 83                                          []
# 84                                          []
# 85                                          []
# 86                                          []
# 87                                          []
# 88                                   [500.000]
# 89                                    [50.000]
# 90                                          []
# 91                                    [10.000]
# 92                                          []
# 93                                          []
# 94                                          []
# 95                                          []
# 96                                          []
# 97                                          []
# 98                                          []
# 99                                          []
# 100                                         []
# 101                                         []
# 102                                         []
# 103                                   [10.000]
# 104                                  [500.000]
# 105                                         []
# 106                                   [70.000]
# 107                                         []
# 108                                         []
# 109                                         []
# 110                                         []
# 111                           [60.000, 87.500]
# 112                       [4.000.000, 300.000]
#
# [113 rows x 1 columns]

# %%
ie_data = merge_data(raw_promo_data, url_data)
ie_data = merge_data(ie_data, discount_data)
ie_data = merge_data(ie_data, price_data)
print(ie_data)
# Out:
#                                                  tweet         username  \
# 0    lazada 11.11.2019 diskon terbesar 24 jam https...        Vallno_07
# 1    @garudacares bagaimana cara tukar mileage disk...           Nug_QA
# 2    sejarah asia tenggara karya m.c. ricklefs rp 3...   KomunitasBambu
# 3    tah diskon 50% cenah..  yuk diserbu..   https:...   AmaAbiyyunShoh
# 4    yaampun kak aulll. eh tapi itu make over lagi ...      tyoungjaems
# 5    pesta harga akhir tahun di giias medan auto sh...      IcanIndopro
# 6    hanya hari ini! shopee promo 11.11 big sale! 1...   katalogpromosi
# 7    cgv cinemas kini hadir di icon mall #gresik . ...         GoersApp
# 8    beli tiket kereta api di @tokopedia diskon 20%...        promo_BRI
# 9    buat kalian yang bisa jajan di alfamart - yuk ...   katalogpromosi
# 10   starbucks promo diskon 50% untuk pembelian min...   katalogpromosi
# 11   sempurnakan alat dapurmu yuk! peralatan dapur ...       alfacartID
# 12   @yrachmania temen gue nitip temennya pas di ho...      urpoisonivy
# 13   prime gears beri diskon menarik helm arai, tai...      motovaganza
# 14   @fiiildzah @gojekindonesia nggak tau nih kak, ...      ademutiaraa
# 15   sesuai janji kami beberapa bulan lalu, kini pr...          bukugpu
# 16   longdress polos renda ukuran: tercantum di gam...        ria_indra
# 17   gmarket lagi ada diskon mega sale nih,  wanna ...        jinhwiyaa
# 18   @indonesiagaruda sdh dcoba berulang2 malah pas...           Nug_QA
# 19   cardholders, jangan lupa yah kalau mau beli ti...      mandiricard
# 20   @benzbara_ @storialco kalau nggak salah, buat ...         iladelfa
# 21   kamu bakalan dapat diskon 25% kalo beli tiket ...     ecogreenpark
# 22   https://t.co/xvvp3ikdvy bekerja sama dengan ko...     KompasTravel
# 23   #pragiwaksono amsterdam teramat menyenangkan. ...           pandji
# 24   hai millenials bogor, kami akan hadir di botan...  JungleLand_Indo
# 25   halo adakah yg buka go prive shirt yg lg disko...        sooisxing
# 26   #sahabatkai, mulai 25 oktober 2018 pemesanan t...           KAI121
# 27   diskon 30% lho... @ new taipei city https://t....    PrimadonnaINA
# 28   @bayu_joo kalo harga 120.000 didiskon spt diat...   nosa_saraswati
# 29   jual buku serba diskon: sejarah islam di tanah...       eswaachmad
# ..                                                 ...              ...
# 83   barang baruuu. masih anget nihh, tengok yuuuu ...  SepatuDocmartku
# 84   diskon toyota bogor, hub: 085701512000 https:/...    Auto2000Bogor
# 85   flash sale telah dimulai! 100 orang pertama ya...       RedDoorzID
# 86   hai seafood lovers. diskon 50% setiap hari unt...       TM_M2S_APG
# 87   untuk mengawali bulan november ini, cobain pak...          yukk_id
# 88   update apps https://t.co/69vhdymxvc sekarang b...     bliblidotcom
# 89   hey, klik linknya dan download app reddoorz sk...      mridwantama
# 90   periode promo klinik kiara healthcare 1 novemb...  KiaraHealthCare
# 91   lelang online dimulai dari harga 10rb hingga f...     bliblidotcom
# 92   tunggu kehadiran kami di pmps (pasar malam per...   XTSquareOffice
# 93   hai aces, memasuki periode november 2018 ace h...     ACEIndonesia
# 94   lewat aplikasi ini, bisa reservasi restoran pl...        detikfood
# 95   untuk mengawali bulan november ini, cobain pak...          yukk_id
# 96   semalem kepikiran pengen beli primer. tau tau ...       agithapepe
# 97   lewat aplikasi ini, bisa reservasi restoran pl...       foodball33
# 98   lewat aplikasi ini, bisa reservasi restoran pl...    SayaSukaMasak
# 99   lewat aplikasi ini, bisa reservasi restoran pl...         redyvine
# 100  lewat aplikasi ini, bisa reservasi restoran pl...     lezatbergizi
# 101  lewat aplikasi ini, bisa reservasi restoran pl...            fbrdn
# 102  lewat aplikasi ini, bisa reservasi restoran pl...   FineCuisineSmg
# 103  dapatkan tambahan diskon hingga 10% khusus bag...   KartuKreditBCA
# 104  cardholders, sudah waktunya mengganti springbe...      mandiricard
# 105  harga gledek 1 hari lagi! nikmati diskon tiket...            tiket
# 106  dibuka prapesan!  mencari bali yang berubah ka...   basabasi_store
# 107  starbucks promo diskon 50% untuk pembelian min...   katalogpromosi
# 108  #repost hushpuppiesid          calm your day w...       Park23Bali
# 109  #jalanjalangratis #ngilanginstres #ngilanginst...  TiketPesawatPro
# 110  kemarin sebelum ke maiyah, sempet nonton ini j...       ShadaHanin
# 111  cukup dengan membawa minimal 2 orang pendampin...   ancoltmnimpian
# 112  2 bioglass 4jt dapet diskon 300rb dapet lagi g...    sellyriantica
#
#                                                   urls    discount  \
# 0                            [https://t.co/8qjlwzwez8]          []
# 1                                                   []       [70%]
# 2    [https://t.co/vietimemom, https://t.co/xxdt22u...          []
# 3                            [https://t.co/4vsqpgan7h]       [50%]
# 4                            [https://t.co/o8kgl937hf]          []
# 5                            [https://t.co/pkivniwwcf]          []
# 6    [https://t.co/2lm7abrakt, https://t.co/9cre7cr...       [90%]
# 7                            [https://t.co/yjjlib7xov]       [20%]
# 8    [https://t.co/1cvgqewbkc, https://t.co/ho4z2ub...       [20%]
# 9    [https://t.co/tqa8sl8mqk, https://t.co/op5s58d...          []
# 10                           [https://t.co/p3dax4wl1c]       [50%]
# 11   [https://t.co/ynd6yiflzy, https://t.co/opb1ozh...       [84%]
# 12                                                  []          []
# 13   [https://t.co/uvtwkflgnb, https://t.co/n6evoiz...          []
# 14                                                  []          []
# 15                           [https://t.co/f9lnzlkyia]       [25%]
# 16                           [https://t.co/rae6xsay2m]          []
# 17                                                  []          []
# 18                                                  []       [70%]
# 19   [https://t.co/mzv5fccxnz, https://t.co/ttl4oua...       [10%]
# 20                                                  []       [50%]
# 21                           [https://t.co/tgrfuhaogr]       [25%]
# 22   [https://t.co/xvvp3ikdvy, https://t.co/i0gusxn...          []
# 23                           [https://t.co/cmqyxulsdf]          []
# 24   [https://t.co/rk8be96tru, https://t.co/87v91bt...          []
# 25                                                  []       [30%]
# 26   [https://t.co/sqedaro4oj,, https://t.co/odjtz4...          []
# 27                           [https://t.co/gdcgvg3fvf]       [30%]
# 28                                                  []       [30%]
# 29                           [https://t.co/h8kduiehqr]          []
# ..                                                 ...         ...
# 83                           [https://t.co/nuii5kxuxu]          []
# 84                           [https://t.co/upx6o9lxel]          []
# 85   [https://t.co/cqvxcqc3fu, https://t.co/3krzbkj...       [25%]
# 86                           [https://t.co/ubg1vs5lxb]       [50%]
# 87                           [https://t.co/ptrxbws6dc]  [10%, 15%]
# 88   [https://t.co/69vhdymxvc, https://t.co/mzikp21...          []
# 89                           [https://t.co/asp9iqlpjy]          []
# 90                           [https://t.co/qe3ljjyzsj]       [35%]
# 91   [https://t.co/69vhdymxvc, https://t.co/o9wnxbe...       [65%]
# 92                                                  []          []
# 93   [https://t.co/prv2n2jyy4, https://t.co/ejrqpgb...          []
# 94                           [https://t.co/kvxyo7js53]       [50%]
# 95                           [https://t.co/mul9xjzqac]  [10%, 15%]
# 96                                                  []       [60%]
# 97   [https://t.co/vzstg6xpwp, https://t.co/khxu9es...       [50%]
# 98   [https://t.co/rl7cjrwvjx, https://t.co/r0mja13...       [50%]
# 99   [https://t.co/mguxh7zp1q, https://t.co/jwt6jmr...       [50%]
# 100  [https://t.co/8qz4ws6ja4, https://t.co/ngmdxof...       [50%]
# 101  [https://t.co/nfdsmjhnbb, https://t.co/ied3e8l...       [50%]
# 102                          [https://t.co/adnbabkhxn]       [50%]
# 103                          [https://t.co/pdsrgtfn8l]   [10%, 0%]
# 104  [https://t.co/h8iyogjvcb, https://t.co/kjkrshk...  [70%, 10%]
# 105  [https://t.co/at2ggfp6wa, https://t.co/txzuqbc...       [50%]
# 106                          [https://t.co/odoyyq9gno]       [25%]
# 107                          [https://t.co/p3dax4eka4]       [50%]
# 108                          [https://t.co/fpbrdnwo41]          []
# 109                          [https://t.co/xaalcmxf2u]          []
# 110                          [https://t.co/evnphubo1q]          []
# 111                          [https://t.co/a15ogx1jkk]       [50%]
# 112                                                 []          []
#
#                                          price
# 0                                           []
# 1                                           []
# 2                           [350.000, 210.000]
# 3                                           []
# 4                                           []
# 5                                           []
# 6                                           []
# 7                                           []
# 8                                    [100.000]
# 9                                           []
# 10                                          []
# 11                                          []
# 12                                    [30.000]
# 13                                          []
# 14                                          []
# 15                                          []
# 16                                   [120.000]
# 17            [25.500, 34.000, 15.800, 20.000]
# 18                                          []
# 19                                          []
# 20                                    [50.000]
# 21                                    [25.000]
# 22                                 [1.000.000]
# 23                                          []
# 24                                          []
# 25                                          []
# 26                                          []
# 27                                          []
# 28   [120.000, 84.000, 36.000, 10.800, 25.200]
# 29                                          []
# ..                                         ...
# 83                                          []
# 84                                          []
# 85                                          []
# 86                                          []
# 87                                          []
# 88                                   [500.000]
# 89                                    [50.000]
# 90                                          []
# 91                                    [10.000]
# 92                                          []
# 93                                          []
# 94                                          []
# 95                                          []
# 96                                          []
# 97                                          []
# 98                                          []
# 99                                          []
# 100                                         []
# 101                                         []
# 102                                         []
# 103                                   [10.000]
# 104                                  [500.000]
# 105                                         []
# 106                                   [70.000]
# 107                                         []
# 108                                         []
# 109                                         []
# 110                                         []
# 111                           [60.000, 87.500]
# 112                       [4.000.000, 300.000]
#
# [113 rows x 5 columns]

# %%
raw_normalized_data = read_csv("integrated_data/normalized.csv",3)
raw_normalized_data = get_by_index(raw_normalized_data, raw_promo_data_index)
print(raw_normalized_data)
# Out:
#                                                  tweet         username
# 0             lazada 11 11 2019 diskon terbesar 24 jam        Vallno_07
# 1     bagaimana cara tukar mileage diskon 70 % garu...           Nug_QA
# 2     sejarah asia tenggara karya m c ricklefs rupi...   KomunitasBambu
# 3                      nah diskon 50 % lho yuk diserbu   AmaAbiyyunShoh
# 4     astaga kak aul eh tapi itu make over lagi dis...      tyoungjaems
# 5     pesta harga akhir tahun di giias medan auto s...      IcanIndopro
# 6     hanya hari ini shopee promo 11 11 big sale 11...   katalogpromosi
# 7     cgv cinemas kini hadir di icon mall dapat dis...         GoersApp
# 8     beli tiket kereta api di diskon 20 % pakai ep...        promo_BRI
# 9     untuk kalian yang bisa jajan di alfamart yuk ...   katalogpromosi
# 10    starbucks promo diskon 50 % untuk beli minuma...   katalogpromosi
# 11    sempurna alat dapur yuk peralatan dapur yang ...       alfacartID
# 12    teman saya titip teman saat di hongkong lagi ...      urpoisonivy
# 13    prime gears beri diskon menarik helm arai tai...      motovaganza
# 14    tidak tahu nih kak tiba2 dapat 10 voucher dis...      ademutiaraa
# 15    sesuai janji kami beberapa bulan lalu kini pr...          bukugpu
# 16    longdress polos renda ukuran tercantum di gam...        ria_indra
# 17    gmarket lagi ada diskon mega sale nih wan na ...        jinhwiyaa
# 18    sudah dicoba berulang2 malah saat bisa pilih ...           Nug_QA
# 19    cardholders jangan lupa ya kalau mau beli tik...      mandiricard
# 20    kalau tidak salah untuk baca espresso saya ha...         iladelfa
# 21    kamu akan dapat diskon 25 % kalau beli tiket ...     ecogreenpark
# 22    bekerja sama dengan korea tourism organizatio...     KompasTravel
# 23    amsterdam sangat senang saya kembali dengan b...           pandji
# 24    hai millenials bogor kami akan hadir di botan...  JungleLand_Indo
# 25    hai adakah yang buka go prive shirt yang lagi...        sooisxing
# 26    mulai 25 oktober 2018 pemesanan tiket via kai...           KAI121
# 27                     diskon 30 % lho new taipei city    PrimadonnaINA
# 28    kalau harga 120 000 diskon seperti atas dapat...   nosa_saraswati
# 29    jual buku serba diskon sejarah islam di tanah...       eswaachmad
# ..                                                 ...              ...
# 83    barang baruuu masih anget nih tengok yuuuu ko...  SepatuDocmartku
# 84            diskon toyota bogor hubungi 085701512000    Auto2000Bogor
# 85    flash sale telah dimulai 100 orang pertama ya...       RedDoorzID
# 86    hai seafood lovers diskon 50 % setiap hari un...       TM_M2S_APG
# 87    untuk mengawali bulan november ini cobain pak...          yukk_id
# 88    update apps sekarang untuk main game dapat ek...     bliblidotcom
# 89    halo klik linknya dan download app reddoorz s...      mridwantama
# 90    periode promo klinik kiara healthcare 1 novem...  KiaraHealthCare
# 91    lelang online dimulai dari harga 10rb hingga ...     bliblidotcom
# 92    tunggu kehadiran kami di pmps pasar malam per...   XTSquareOffice
# 93    hai aces memasuki periode november 2018 ace h...     ACEIndonesia
# 94    lewat aplikasi ini bisa reservasi restoran pl...        detikfood
# 95    untuk mengawali bulan november ini cobain pak...          yukk_id
# 96    semalem terpikir ingin beli primer tahu tahu ...       agithapepe
# 97    lewat aplikasi ini bisa reservasi restoran pl...       foodball33
# 98    lewat aplikasi ini bisa reservasi restoran pl...    SayaSukaMasak
# 99    lewat aplikasi ini bisa reservasi restoran pl...         redyvine
# 100   lewat aplikasi ini bisa reservasi restoran pl...     lezatbergizi
# 101   lewat aplikasi ini bisa reservasi restoran pl...            fbrdn
# 102   lewat aplikasi ini bisa reservasi restoran pl...   FineCuisineSmg
# 103   dapat tambahan diskon hingga 10 % khusus bagi...   KartuKreditBCA
# 104   cardholders sudah waktu ganti springbed janga...      mandiricard
# 105   harga petir 1 hari lagi nikmati diskon tiket ...            tiket
# 106   buka prapesan mencari bali yang berubah karya...   basabasi_store
# 107   starbucks promo diskon 50 % untuk beli minuma...   katalogpromosi
# 108   hushpuppiesid calm your day with the blue cho...       Park23Bali
# 109                    tiket pesawat murah diskon klik  TiketPesawatPro
# 110   kemarin sebelum ke maiyah sempat nonton ini j...       ShadaHanin
# 111   cukup dengan membawa minimal 2 orang pendampi...   ancoltmnimpian
# 112   2 bioglass 4jt dapat diskon 300rb dapat lagi ...    sellyriantica
#
# [113 rows x 2 columns]

# %% [markdown]
# ## Eksperimen Post Tag dengan Gradient descent using the L-BFGS method

# %%
def read_pos_tag_corpus(file_name,sample_count=1000):
    with open(file_name, 'r', encoding='utf-8') as f:
        lines = f.read().split('\n')
    pair = []
    all_pair = []
    for line in lines[: min(sample_count, len(lines))]:
        if line == '':
            all_pair.append(pair)
            pair = []
        else:
            kata, tag = line.split('\t')
            p = (kata.lower(),tag)
            pair.append(p)
    return all_pair

pos_tag_corpus = read_pos_tag_corpus("text_corpus/Indonesian_Manually_Tagged_Corpus.txt")
print(pos_tag_corpus)
# Out:
# [[('kera', 'NN'), ('untuk', 'SC'), ('amankan', 'VB'), ('pesta olahraga', 'NN')], [('pemerintah', 'NNP'), ('kota', 'NNP'), ('delhi', 'NNP'), ('mengerahkan', 'VB'), ('monyet', 'NN'), ('untuk', 'SC'), ('mengusir', 'VB'), ('monyet-monyet', 'NN'), ('lain', 'JJ'), ('yang', 'SC'), ('berbadan', 'VB'), ('lebih', 'RB'), ('kecil', 'JJ'), ('dari', 'IN'), ('arena', 'NN'), ('pesta olahraga', 'NNP'), ('persemakmuran', 'NNP'), ('.', 'Z')], [('beberapa', 'CD'), ('laporan', 'NN'), ('menyebutkan', 'VB'), ('setidaknya', 'RB'), ('10', 'CD'), ('monyet', 'NN'), ('ditempatkan', 'VB'), ('di', 'IN'), ('luar', 'NN'), ('arena', 'NN'), ('lomba', 'NN'), ('dan', 'CC'), ('pertandingan', 'NN'), ('di', 'IN'), ('ibukota', 'NNP'), ('india', 'NNP'), ('.', 'Z')], [('pemkot', 'NNP'), ('delhi', 'NNP'), ('memiliki', 'VB'), ('28', 'CD'), ('monyet', 'NN'), ('dan', 'CC'), ('berencana', 'VB'), ('mendatangkan', 'VB'), ('10', 'CD'), ('monyet', 'NN'), ('sejenis', 'NN'), ('dari', 'IN'), ('negara bagian', 'NNP'), ('rajasthan', 'NNP'), ('.', 'Z')], [('jumlah', 'NN'), ('monyet', 'NN'), ('di', 'IN'), ('ibukota', 'NNP'), ('india', 'NNP'), ('mencapai', 'VB'), ('ribuan', 'CD'), (',', 'Z'), ('sebagian besar', 'NN'), ('berada', 'VB'), ('di', 'IN'), ('kantor-kantor', 'NN'), ('pemerintah', 'NN'), ('dan', 'CC'), ('hewan', 'NN'), ('ini', 'PR'), ('dianggap', 'VB'), ('mengganggu', 'VB'), ('ketertiban', 'NN'), ('umum', 'JJ'), ('.', 'Z')], [('jenis', 'NN'), ('monyet', 'NN'), ('yang', 'SC'), ('dikerahkan', 'VB'), ('pemkot', 'NN'), ('berbadan', 'VB'), ('besar', 'JJ'), (',', 'Z'), ('berekor', 'VB'), ('panjang', 'JJ'), (',', 'Z'), ('dan', 'CC'), ('memiliki', 'VB'), ('wajah', 'NN'), ('berwarna', 'VB'), ('hitam', 'JJ'), ('.', 'Z')], [('monyet', 'NN'), ('ini', 'PR'), ('diikat', 'VB'), ('dengan', 'IN'), ('tali', 'NN'), ('panjang', 'JJ'), ('dan', 'CC'), ('pelatih', 'NN'), ('yang', 'SC'), ('mengawasi', 'VB'), ('mereka', 'PRP'), ('akan', 'MD'), ('melepas', 'VB'), ('tali', 'NN'), ('begitu', 'SC'), ('monyet-monyet', 'NN'), ('kecil', 'JJ'), ('lain', 'JJ'), ('mendekat', 'VB'), ('.', 'Z')], [('kantor', 'NNP'), ('berita', 'NNP'), ('afp', 'NNP'), ('melaporkan', 'VB'), ('stadion', 'NN'), ('tinju', 'NN'), ('dan', 'CC'), ('hockey', 'FW'), ('mendapatkan', 'VB'), ('perhatian', 'NN'), ('khusus', 'JJ'), ('karena', 'SC'), ('sering', 'RB'), ('diserbu', 'VB'), ('monyet', 'NN'), ('.', 'Z')], [('monyet', 'NN'), ('besar', 'JJ'), ('akan', 'MD'), ('dikerahkan', 'VB'), ('di', 'IN'), ('dua', 'CD'), ('stadion', 'NN'), ('untuk', 'SC'), ('mengusir', 'VB'), ('serbuan', 'NN'), ('monyet', 'NN'), ('kecil', 'JJ')], [('"', 'Z'), ('monyet', 'NN'), ('besar', 'JJ'), ('akan', 'MD'), ('dikerahkan', 'VB'), ('di', 'IN'), ('dua', 'CD'), ('stadion', 'NN'), ('tersebut', 'PR'), ('untuk', 'SC'), ('mengusir', 'VB'), ('serbuan', 'NN'), ('monyet', 'NN'), ('kecil', 'JJ'), (',', 'Z'), ('"', 'Z'), ('kata', 'VB'), ('devender', 'NNP'), ('prasad', 'NNP'), (',', 'Z'), ('pejabat', 'NN'), ('pemerintah', 'NNP'), ('kota', 'NNP'), ('delhi', 'NNP'), ('kepada', 'IN'), ('kantor berita', 'NNP'), ('afp', 'NNP'), ('.', 'Z')], [('selama', 'IN'), ('bertahun-tahun', 'CD'), ('monyet', 'NN'), ('mengganggu', 'VB'), ('warga', 'NN'), ('delhi', 'NNP'), ('.', 'Z')], [('binatang', 'NN'), ('ini', 'PR'), ('menaiki', 'VB'), ('kereta', 'NN'), ('metro', 'NN'), ('dan', 'CC'), ('bahkan', 'RB'), ('berkeliaran', 'VB'), ('di', 'IN'), ('kompleks', 'NN'), ('gedung', 'NN'), ('parlemen', 'NN'), ('.', 'Z')], [('belum', 'NEG'), ('lama', 'JJ'), ('ini', 'PR'), ('kawanan', 'NN'), ('monyet', 'NN'), ('menyerbu', 'VB'), ('kantor', 'NN'), ('perdana menteri', 'NN'), ('dan', 'CC'), ('departemen', 'NN'), ('pertahanan', 'NN'), ('.', 'Z')], [('binatang', 'NN'), ('ini', 'PR'), ('tidak', 'NEG'), ('bisa', 'MD'), ('dibunuh', 'VB'), ('karena', 'SC'), ('masyarakat', 'NN'), ('india', 'NNP'), ('menganggap', 'VB'), ('mereka', 'PRP'), ('suci', 'JJ'), ('.', 'Z')], [('selain', 'CC'), ('harus', 'MD'), ('mengusir', 'VB'), ('kawanan', 'NN'), ('monyet', 'NN'), (',', 'Z'), ('pemkot', 'NNP'), ('delhi', 'NNP'), ('juga', 'RB ...

# %%
def word2features(sent, i):
    word = sent[i][0]
    postag = sent[i][1]
    features = [
        'bias',
        'word.lower=' + word.lower(),
        'word[-3:]=' + word[-3:],
        'word[-2:]=' + word[-2:],
        'word.isupper=%s' % word.isupper(),
        'word.istitle=%s' % word.istitle(),
        'word.isdigit=%s' % word.isdigit(),
        #'postag=' + postag,
        #'postag[:2]=' + postag[:2],
    ]
    if i > 0:
        word1 = sent[i-1][0]
        postag1 = sent[i-1][1]
        features.extend([
            '-1:word.lower=' + word1.lower(),
            '-1:word.istitle=%s' % word1.istitle(),
            '-1:word.isupper=%s' % word1.isupper(),
            '-1:postag=' + postag1,
            '-1:postag[:2]=' + postag1[:2],
        ])
    else:
        features.append('BOS')
        
    if i < len(sent)-1:
        word1 = sent[i+1][0]
        postag1 = sent[i+1][1]
        features.extend([
            '+1:word.lower=' + word1.lower(),
            '+1:word.istitle=%s' % word1.istitle(),
            '+1:word.isupper=%s' % word1.isupper(),
            '+1:postag=' + postag1,
            '+1:postag[:2]=' + postag1[:2],
        ])
    else:
        features.append('EOS')
                
    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [postag for token, postag in sent]

def sent2tokens(sent):
    return [token for token, postag in sent]

print(sent2features(pos_tag_corpus[0])[0])
# Out:
# ['bias', 'word.lower=kera', 'word[-3:]=era', 'word[-2:]=ra', 'word.isupper=False', 'word.istitle=False', 'word.isdigit=False', 'BOS', '+1:word.lower=untuk', '+1:word.istitle=False', '+1:word.isupper=False', '+1:postag=SC', '+1:postag[:2]=SC']

# %%
X = [sent2features(s) for s in pos_tag_corpus]
y = [sent2labels(s) for s in pos_tag_corpus]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

print(X_train)
# Out:
# [[['bias', 'word.lower=salah satu', 'word[-3:]=atu', 'word[-2:]=tu', 'word.isupper=False', 'word.istitle=False', 'word.isdigit=False', 'BOS', '+1:word.lower=dari', '+1:word.istitle=False', '+1:word.isupper=False', '+1:postag=IN', '+1:postag[:2]=IN'], ['bias', 'word.lower=dari', 'word[-3:]=ari', 'word[-2:]=ri', 'word.isupper=False', 'word.istitle=False', 'word.isdigit=False', '-1:word.lower=salah satu', '-1:word.istitle=False', '-1:word.isupper=False', '-1:postag=CD', '-1:postag[:2]=CD', '+1:word.lower=pihak', '+1:word.istitle=False', '+1:word.isupper=False', '+1:postag=NN', '+1:postag[:2]=NN'], ['bias', 'word.lower=pihak', 'word[-3:]=hak', 'word[-2:]=ak', 'word.isupper=False', 'word.istitle=False', 'word.isdigit=False', '-1:word.lower=dari', '-1:word.istitle=False', '-1:word.isupper=False', '-1:postag=IN', '-1:postag[:2]=IN', '+1:word.lower=yang', '+1:word.istitle=False', '+1:word.isupper=False', '+1:postag=SC', '+1:postag[:2]=SC'], ['bias', 'word.lower=yang', 'word[-3:]=ang', 'word[-2:]=ng', 'word.isupper=False', 'word.istitle=False', 'word.isdigit=False', '-1:word.lower=pihak', '-1:word.istitle=False', '-1:word.isupper=False', '-1:postag=NN', '-1:postag[:2]=NN', '+1:word.lower=berselisih', '+1:word.istitle=False', '+1:word.isupper=False', '+1:postag=VB', '+1:postag[:2]=VB'], ['bias', 'word.lower=berselisih', 'word[-3:]=sih', 'word[-2:]=ih', 'word.isupper=False', 'word.istitle=False', 'word.isdigit=False', '-1:word.lower=yang', '-1:word.istitle=False', '-1:word.isupper=False', '-1:postag=SC', '-1:postag[:2]=SC', '+1:word.lower=,', '+1:word.istitle=False', '+1:word.isupper=False', '+1:postag=Z', '+1:postag[:2]=Z'], ['bias', 'word.lower=,', 'word[-3:]=,', 'word[-2:]=,', 'word.isupper=False', 'word.istitle=False', 'word.isdigit=False', '-1:word.lower=berselisih', '-1:word.istitle=False', '-1:word.isupper=False', '-1:postag=VB', '-1:postag[:2]=VB', '+1:word.lower=adalah', '+1:word.istitle=False', '+1:word.isupper=False', '+1:postag=VB', '+1:postag[:2]=VB'], ['bias', 'word.lower=adalah', 'word[-3:]=lah', 'word[-2:]=ah', 'word.isupper=False', 'word.istitle=False', 'word.isdigit=False', '-1:word.lower=,', '-1:word.istitle=False', '-1:word.isupper=False', '-1:postag=Z', '-1:postag[:2]=Z', '+1:word.lower=anthony', '+1:word.istitle=False', '+1:word.isupper=False', '+1:postag=NNP', '+1:postag[:2]=NN'], ['bias', 'word.lower=anthony', 'word[-3:]=ony', 'word[-2:]=ny', 'word.isupper=False', 'word.istitle=False', 'word.isdigit=False', '-1:word.lower=adalah', '-1:word.istitle=False', '-1:word.isupper=False', '-1:postag=VB', '-1:postag[:2]=VB', '+1:word.lower=thomas', '+1:word.istitle=False', '+1:word.isupper=False', '+1:postag=NNP', '+1:postag[:2]=NN'], ['bias', 'word.lower=thomas', 'word[-3:]=mas', 'word[-2:]=as', 'word.isupper=False', 'word.istitle=False', 'word.isdigit=False', '-1:word.lower=anthony', '-1:word.istitle=False', '-1:word.isupper=False', '-1:postag=NNP', '-1:postag[:2]=NN', '+1:word.lower=ahli', '+1:word.istitle=False', '+1:word.isupper=False', '+1:postag=NN', '+1:postag[:2]=NN'], ['bias', 'word.lower=ahli', 'word[-3:]=hli', 'word[-2:]=li', 'word.isupper=False', 'word.istitle=False', 'word.isdigit=False', '-1:word.lower=thomas', '-1:word.istitle=False', '-1:word.isupper=False', '-1:postag=NNP', '-1:postag[:2]=NN', '+1:word.lower=konstruksi', '+1:word.istitle=False', '+1:word.isupper=False', '+1:postag=NN', '+1:postag[:2]=NN'], ['bias', 'word.lower=konstruksi', 'word[-3:]=ksi', 'word[-2:]=si', 'word.isupper=False', 'word.istitle=False', 'word.isdigit=False', '-1:word.lower=ahli', '-1:word.istitle=False', '-1:word.isupper=False', '-1:postag=NN', '-1:postag[:2]=NN', '+1:word.lower=dari', '+1:word.istitle=False', '+1:word.isupper=False', '+1:postag=IN', '+1:postag[:2]=IN'], ['bias', 'word.lower=dari', 'word[-3:]=ari', 'word[-2:]=ri', 'word.isupper=False', 'word.istitle=False', 'word.isdigit=False', '-1:word.lower=konstruksi', '-1:word.istitle=False', '-1:word.isupper=False', '-1:postag=NN', '-1:postag[:2]=NN', '+1:word.lower=kalif ...

# %%
trainer = pycrfsuite.Trainer(algorithm='lbfgs',verbose=False)

for xseq, yseq in zip(X_train, y_train):
    trainer.append(xseq, yseq)
    
trainer.set_params({
    'c1': 1.0,   # coefficient for L1 penalty
    'c2': 1e-3,  # coefficient for L2 penalty
    'max_iterations': 50,  # stop earlier

    # include transitions that are possible, but not observed
    'feature.possible_transitions': True
})

print(trainer.params())

trainer.train('conll2002-esp.crfsuite')
# Out:
# ['feature.minfreq', 'feature.possible_states', 'feature.possible_transitions', 'c1', 'c2', 'max_iterations', 'num_memories', 'epsilon', 'period', 'delta', 'linesearch', 'max_linesearch']

# %%
trainer.logparser.last_iteration
# Out:
# {'active_features': 528,
#  'error_norm': 12.68808,
#  'feature_norm': 26.273679,
#  'linesearch_step': 1.0,
#  'linesearch_trials': 1,
#  'loss': 809.239624,
#  'num': 50,
#  'scores': {},
#  'time': 0.002}

# %%
# !ls -lh ./conll2002-esp.crfsuite
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
tagger = pycrfsuite.Tagger()
tagger.open('conll2002-esp.crfsuite')

# %%
example_sent = pos_tag_corpus[0]
print(example_sent)
print(' '.join(sent2tokens(example_sent)), end='\n\n')

print("Predicted:", ' '.join(tagger.tag(sent2features(example_sent))))
print("Correct:  ", ' '.join(sent2labels(example_sent)))
# Out:
# [('kera', 'NN'), ('untuk', 'SC'), ('amankan', 'VB'), ('pesta olahraga', 'NN')]
# kera untuk amankan pesta olahraga
#
# Predicted: NN SC VB NN
# Correct:   NN SC VB NN

# %%
def postag_classification_report(y_true, y_pred):
    lb = preprocessing.LabelBinarizer()
    y_true_combined = lb.fit_transform(list(chain.from_iterable(y_true)))
    y_pred_combined = lb.transform(list(chain.from_iterable(y_pred)))
        
    tagset = set(lb.classes_) - {'O'}
    tagset = sorted(tagset, key=lambda tag: tag.split('-', 1)[::-1])
    class_indices = {cls: idx for idx, cls in enumerate(lb.classes_)}
    
    return classification_report(
        y_true_combined,
        y_pred_combined,
        labels = [class_indices[cls] for cls in tagset],
        target_names = tagset,
    )

# %%
y_pred = [tagger.tag(xseq) for xseq in X_test]

# %%
print(postag_classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#          CC       1.00      0.75      0.86         4
#          CD       1.00      0.50      0.67         4
#          FW       0.00      0.00      0.00         1
#          IN       0.75      0.75      0.75         4
#          JJ       0.60      0.43      0.50         7
#          MD       0.67      1.00      0.80         4
#         NEG       1.00      1.00      1.00         1
#          NN       0.57      0.95      0.71        21
#         NNP       0.75      0.86      0.80         7
#          PR       1.00      1.00      1.00         2
#         PRP       1.00      1.00      1.00         7
#          RB       0.00      0.00      0.00         3
#          RP       0.00      0.00      0.00         1
#          SC       0.75      0.43      0.55         7
#          VB       0.86      0.67      0.75        18
#           Z       1.00      1.00      1.00         7
#
# avg / total       0.74      0.74      0.72        98
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ## Input NNP ke Information Extraction

# %%
def words_list(text):
    return(nltk.word_tokenize(text))

def generate_post_tag(text):
    word_array = np.array(words_list(text))
    return tagger.tag(sent2features(word_array))
    #return ct.tag_sents(word_array)
    
generate_post_tag("lazada 11 11 2019 diskon terbesar 24 jam")
# Out:
# ['NN', 'CD', 'CD', 'CD', 'NN', 'NN', 'CD', 'NN']

# %%
def get_nnp_index(text):
    index_array = []
    filter_text = filter_one_character(text)
    filter_text = filter_not_alphanumeric(filter_text)
    #filter_text = filter_number(filter_text)
    tag_result = generate_post_tag(filter_text)
    for i in range(len(tag_result)):
        if (tag_result[i] == 'NNP'):
            index_array.append(i)
    return index_array

def filter_one_character(text):
    return(re.sub(r"\b[%a-zA-Z0-9]\b", "", text))

def filter_not_alphanumeric(text):
    return(re.sub(r'[^\w]', ' ', text))

def filter_number(text):
    return(re.sub(r'[0-9]', '', text))

def get_nnp(text):
    nnp_index = get_nnp_index(text)
    word_array = words_list(text)
    result = []
    for i in range(len(nnp_index)):
        result.append([word_array[nnp_index[i]]])
    return result

def get_nnp_data(data):
    numpy_data = data.copy(deep=True)
    numpy_data = np.array(numpy_data)
    new_data = []
    for i in range(len(numpy_data)):
        result = get_nnp(numpy_data[i][0])
        new_data.append(result)
    new_data = np.array(new_data)
    if (new_data.size > 0):
        new_data = pd.DataFrame(new_data,columns=["nnp"])
    return(new_data)

# %%
nnp_data = get_nnp_data(raw_normalized_data)
if (nnp_data.size > 0):
    ie_data = merge_data(ie_data, nnp_data)

# %%
save_as_csv("info_extract_data/info_extract.csv",ie_data)
